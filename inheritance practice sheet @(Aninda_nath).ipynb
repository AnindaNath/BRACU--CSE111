# %%
#problem 1
class PlayerEarning:
    def __init__(self,name):
        self.name=name
        self.bonus=0
        # self.W_bonus=0
    def calculateTotal(self,W_bonus,bonus=0):
        self.W_bonus=W_bonus
        self.bonus=bonus
    def printDetails(self):
        print(f"Player Name: {self.name}")
        print(f'Player season Earning without bonus: {self.W_bonus}')
        if self.bonus==0:
            print("Bonus:", self.bonus)
            print("Player Season Earning After Bonus: ", self.W_bonus )
        elif self.bonus>30:
            
            x=round((5/100)*self.W_bonus+10000,0)
            print("Bonus:",int(x))
            print("Player Season Earning After Bonus: ", self.W_bonus + int(x))
        else:
            x=(5/100)*self.W_bonus
            print("Bonus:",int( x))
            print("Player Season Earning After Bonus: ", self.W_bonus + int(x))

print("**********************")
player1 = PlayerEarning('Buffon')
player1.calculateTotal(250000)
player1.printDetails()
print("\n**********************")
player2 = PlayerEarning('Dybala')
player2.calculateTotal(250000, 31)
player2.printDetails()
print("\n**********************")
player3 = PlayerEarning('Cuadrado')
player3.calculateTotal(250000, 20)
player3.printDetails()
# Out:
# **********************
# Player Name: Buffon
# Player season Earning without bonus: 250000
# Bonus: 0
# Player Season Earning After Bonus:  250000
#
# **********************
# Player Name: Dybala
# Player season Earning without bonus: 250000
# Bonus: 22500
# Player Season Earning After Bonus:  272500
#
# **********************
# Player Name: Cuadrado
# Player season Earning without bonus: 250000
# Bonus: 12500
# Player Season Earning After Bonus:  262500

# %%
#problem 2
class myList:
    def __init__(self,*number): 
        print(number)  # int list alwayas
        if len(number)==0:
            self.sum1=0
            self.counter=0
            self.list1=[]
            self.marge=[]
           
        else:
            self.list1=[]
            self.marge=[]
            self.sum1=0
            self.counter=0
        
        for i in number:
            self.list1.append(i)
            self.counter+=1
    def sum(self):
        if len(self.marge)!=0:
            for i in self.marge:
                self.sum1+=i
        else:
            for i in self.list1:
                self.sum1+=i
        print("Sum:",self.sum1)
    def merge(self,*number):
        for i in number:
            self.marge.append(i)
            self.counter+=1
    def average(self):
        if self.sum1==0:
            print("Average:",0)
        else:
            print("Average:",self.sum1/self.counter)
l1 = myList(2,3,4,5,6)
l1.sum()
l1.merge(4,5,9)
l1.sum()
l1.average()
print("-----------------------------")
l2 = myList()
l2.average()
l2.merge(1,2,4,8)
l2.sum()
# Out:
# (2, 3, 4, 5, 6)
# Sum: 20
# Sum: 38
# Average: 4.75
# -----------------------------
# ()
# Average: 0
# Sum: 15

# %%
# problem 3
class Bird:
    def __init__(self,name,positon=False):
        self.name=name
        self.position=positon
        self.type =" Flightless Birds"

    def fly(self):
        if self.position==True:
            print(f'{self.name} can fly')
        else:
            print(f'{self.name} can not fly')
    def setType(self,type):
        self.type=type

    def printDetail(self):

        print(f"Name: {self.name}")
        print(f'Type: {self.type}')
ostrich = Bird('Ostrich')
duck = Bird("Duck", True)
owl = Bird('Owl', True)
print("###########################")
ostrich.fly()
duck.fly()
owl.fly()
duck.setType('Water Birds')
owl.setType('Birds of Prey')
print("=========================")
ostrich.printDetail()
print("=========================")
duck.printDetail()
print("=========================")
owl.printDetail()
# Out:
# ###########################
# Ostrich can not fly
# Duck can fly
# Owl can fly
# ...
# Name: Ostrich
# Type:  Flightless Birds
# ...
# Name: Duck
# Type: Water Birds
# ...
# Name: Owl
# Type: Birds of Prey

# %%
# problem 4
class Account:
    count=0
    def __init__(self,name,age,occupation,amount):
        self.name=name
        self.age=age
        self.occupation=occupation
        self.amount=amount
        Account.count+=1
    def addMoney(self,add_money):
        self.amount+=add_money
    def withdrawMoney(self,minus_amount):
        self.amount=minus_amount-self.amount

    def printDetails(self):
        print("Name",self.name)
        print("Age:",self.age)
        print("Occupatiion:",self.occupation)
        print("Total amount:",self.amount)

print('No of account holders:', Account.count)
print("=========================")
p1 = Account("Abdul", 45, "Service Holder", 500000)
p1.addMoney(300000)
p1.printDetails()
print("=========================")
p2 = Account("Rahim", 55, "Businessman", 700000)
p2.withdrawMoney(700000)
p2.printDetails()
print("=========================")
p3 = Account("Ashraf", 62, "Govt. Officer", 200000)
p3.withdrawMoney(250000)
p3.printDetails()
print("=========================")
print('No of account holders:', Account.count)
# Out:
# No of account holders: 0
# ...
# Name Abdul
# Age: 45
# Occupatiion: Service Holder
# Total amount: 800000
# ...
# Name Rahim
# Age: 55
# Occupatiion: Businessman
# Total amount: 0
# ...
# Name Ashraf
# Age: 62
# Occupatiion: Govt. Officer
# Total amount: 50000
# ...
# No of account holders: 3

# %%
#problem 5
class Smartphone:
    def __init__(self,name=" "):
        self.name=name
        self.dis=[]
        self.ram=[]
    def addFeature(self,dis,size):
        if dis=="Display":
            if size not in self.dis:
                self.dis.append(size)
        else:
            if size not in self.ram:
                self.ram.append(size)

        if self.name==" ":
            print("Feature can not be added without phone name")

    def setName(self,name1):
        self.name=name1
    def printDetail(self):
        print(f'Phone name: {self.name}')
        if len(self.dis)!=0:
            x=""
            counter=1
            for i in self.dis:
                if len(self.dis)==counter:
                    x+=i
                else:
                    x+=i+","
                counter+=1
            print(f'Display: {x}')

        if len(self.ram)!=0:
            y=''
            counter=1
            for j in self.ram:
                if len(self.ram)==counter:
                    y+=j
                else:
                    y+=j+","
                counter+=1
            print(f'Ram: {y}')
s1 = Smartphone()
print("=================================")
s1.addFeature("Display", "6.1 inch")
print("=================================")
s1.setName("Samsung Note 20")
s1.addFeature("Display", "6.1 inch")
s1.printDetail()
print("=================================")
s2 = Smartphone("Iphone 12 Pro")
s2.addFeature("Display", "6.2 inch")
s2.addFeature("Ram", "6 GB")
print("=================================")
s2.printDetail()
s2.addFeature("Display", "Amoled panel")
s2.addFeature("Ram", "DDR5")
print("=================================")
s2.printDetail()
print("=================================")
# Out:
# ...
# Feature can not be added without phone name
# ...
# Phone name: Samsung Note 20
# Display: 6.1 inch
# ...
# Phone name: Iphone 12 Pro
# Display: 6.2 inch
# Ram: 6 GB
# ...
# Phone name: Iphone 12 Pro
# Display: 6.2 inch,Amoled panel
# Ram: 6 GB,DDR5
# ...

# %%
# problem 6
class Student:
    count=0
    cse_student=0
    bba_student=0
    def __init__(self,name,dept):
        self.name=name
        self.dept=dept
        Student.count+=1
        self.id = Student.count
        print("Creating Student Number:", Student.count)

        if dept=="CSE":
            Student.cse_student+=1
        elif dept=="BBA":
            Student.bba_student+=1
    def individualInfo(self):
        if self.dept=="CSE":
            print(f"{self.name} is from {self.dept} department.")
            print(f"Serial of {self.name}  among all student's is :{self.id}")
            print(f'Serial of {self.name} in CSE department is: {Student.cse_student}')
        elif self.dept=="BBA":
            print(f"{self.name} is from {self.dept} department.")
            print(f"Serial of {self.name}  among all student's is :{self.id}")
            print(f'Serial of {self.name} in BBA department is: {Student.bba_student}')

    def totalInfo(self):
        print(f'Total Number of Student: {Student.count}')
        print(f'Total Number of CSE Student: {Student.cse_student}')
        print(f'Total Number of BBA student: {Student.bba_student}')
s1 = Student("Naruto", "CSE")
print('----------------------')
s1.individualInfo()
print('#############################')
s1.totalInfo()
print('============================')
s2 = Student("Sakura", "BBA")
print('----------------------')
s2.individualInfo()
print('#############################')
s2.totalInfo()
print('============================')
s3 = Student("Shikamaru", "CSE")
print('----------------------')
s3.individualInfo()
print('#############################')
s3.totalInfo()
print('============================')
s4 = Student("Deidara", "BBA")
print('----------------------')
s4.individualInfo()
print('#############################')
s4.totalInfo()
# Out:
# Creating Student Number: 1
# ----------------------
# Naruto is from CSE department.
# Serial of Naruto  among all student's is :1
# Serial of Naruto in CSE department is: 1
# #############################
# Total Number of Student: 1
# Total Number of CSE Student: 1
# Total Number of BBA student: 0
# ...
# Creating Student Number: 2
# ----------------------
# Sakura is from BBA department.
# Serial of Sakura  among all student's is :2
# Serial of Sakura in BBA department is: 1
# #############################
# Total Number of Student: 2
# Total Number of CSE Student: 1
# Total Number of BBA student: 1
# ...
# Creating Student Number: 3
# ----------------------
# Shikamaru is from CSE department.
# Serial of Shikamaru  among all student's is :3
# Serial of Shikamaru in CSE department is: 2
# #############################
# Total Number of Student: 3
# Total Number of CSE Student: 2
# Total Number of BBA student: 1
# ...
# Creating Student Number: 4
# ----------------------
# ...

# %%
# problem 7

class book:
    def __init__(self, name):
        self.name = name
        self.genre='biography'
    def review(self):
        print('This book is just out of theworld,mind-blowing!')
# Write your code here
class fiction(book):
    def __init__(self,name,genre=''):
        super().__init__(name)
        self.genre=genre
    def review(self):
        print(f'{self.name} is a {self.genre} is just out of theworld,mind-blowing! ')
class nonfiction(book):
    def review(self):
        print(f'{self.name} is a {self.genre} is just out of theworld,mind-blowing! ')



b1 = fiction('The Shining','Psychologicalhorror')
b2 = nonfiction('A Beautiful Mind')
b1.review()
print('=========================')
b2.review()
print('=========================')
# Out:
# The Shining is a Psychologicalhorror is just out of theworld,mind-blowing!
# ...
# A Beautiful Mind is a biography is just out of theworld,mind-blowing!
# ...

# %%
# problem 8
class Processor:
    def __init__(self, model, thread, core):
        self.model = model
        self.core = core
        self.thread = thread

    def getInfo(self):
        return "Model:"+self.model + "\nCores:"+str(self.core) + "\nThreads:"+ str(self.thread)
# Write your code here
class Intel(Processor):
    def __init__(self,model,core,thread,price):
        super().__init__(model,thread,core)
        self.price=price
    def getInfo(self):
        print(f'{super().getInfo()} \nPrice: {self.price}')
class AMD(Processor):
    def __init__(self,model,core,thread,price):
        super().__init__(model, thread, core)
        self.price = price
    def getInfo(self):
        print(f'{super().getInfo()} \nPrice: {self.price}')
p1 = Intel("Intel i5 10th Gen",6,12,17000)
p2 = AMD("Ryzen 5 3500X",6,6,13800)
p3 = AMD("Ryzen 5 3600",6,12,16900)
print('======================')
p1.getInfo()
print('======================')
p2.getInfo()
print('======================')
p3.getInfo()
# Out:
# ...
# Model:Intel i5 10th Gen
# Cores:6
# Threads:12
# Price: 17000
# ...
# Model:Ryzen 5 3500X
# Cores:6
# Threads:6
# Price: 13800
# ...
# Model:Ryzen 5 3600
# Cores:6
# Threads:12
# Price: 16900

# %%
# problem 9

class Fruit:
    Total_order=0
    def __init__(self, Order_ID, weight):
        self.Order_ID=Order_ID
        self.weight=weight
        Fruit.Total_order=Fruit.Total_order+1
    def __str__(self):
        return self.Order_ID+", Weight:"+str(self.weight)
class Mango(Fruit):
    def __init__(self,order_id,weight,variety,total_price):
        super().__init__(order_id,weight)
        self.variety=variety
        self.total_price=total_price*self.weight
    def __str__(self):
        return super().__str__()+",Varity:"+self.variety+",Total price:"+str(self.total_price)
    def __add__(self,other):
        x=self.total_price+other.total_price
        return f'The total Price of the orders are: {x}'

#write your code here
class JackFruit(Fruit):
    def __init__(self,order_id,weight,price):
        super().__init__(order_id,weight)
        self.price=price*self.weight
    def __str__(self):
        return super().__str__()+",Total price:"+str(self.price)
    def __add__(self,other):
        x=self.price+other.price
        return f'The total Price of the orders are: {x}'

#write your code here
m1=Mango("Order Id 1", 5,"GopalVog",250)
print(m1)
m2=Mango("Order Id 2", 5,"HariVanga", 230)
print(m2)
j1=JackFruit("Order Id 3", 5,250)
print(j1)
j2=JackFruit("Order Id 4", 4,210)
print(j2)
print("Total number of Orders:"+str(Fruit.Total_order))
print("==================")
print(m1+m2)
print("==================")
print(j1+j2)
# Out:
# Order Id 1, Weight:5,Varity:GopalVog,Total price:1250
# Order Id 2, Weight:5,Varity:HariVanga,Total price:1150
# Order Id 3, Weight:5,Total price:1250
# Order Id 4, Weight:4,Total price:840
# Total number of Orders:4
# ...
# The total Price of the orders are: 2400
# ...
# The total Price of the orders are: 2090

# %%
# problem 10 
class Student:
    def __init__(self,name,ID):
        self.name = name
        self.ID = ID
    def Details(self):
        return "Name: "+self.name+"\n"+"ID: "+self.ID+"\n"
#Write your code here
class CSEStudent(Student):
    def __init__(self,name,id,semester):
        super().__init__(name,id)
        self.semester=semester
        self.dict1={}
    def Details(self):
         return super().Details()+"Current semester: "+str(self.semester)
    def addCourseWithMarks(self,*result):
        for i in range(0,len(result),2):
            if result[i] not in self.dict1.keys():
                self.dict1[result[i]]=int(result[i+1])
    def showGPA(self):
        
        y=len(self.dict1)*3
        
        print(f"{self.name} has taken {len(self.dict1)} courses")
        sum1=0
        per_course_creadit=0
        for key,val in self.dict1.items():
            if val>85:
                sum1+=4.0*3
                per_course_creadit+=3
            elif 80<=val<=84:
                sum1+=3.3*3
                per_course_creadit += 3
            elif 70<=val<=79:
                sum1+=3.0*3
                per_course_creadit += 3
            elif 65<=val<=69:
                sum1+=2.3*3
                per_course_creadit += 3
            elif 57<=val<=64:
                sum1+=2.0*3
                per_course_creadit += 3
            elif 55<=val<=56:
                sum1+=1.3*3
                per_course_creadit += 3
            if val>50:
                print(f'{key}:{val}')
            else:
                print(f'{key}:0.0')
                
       
        
        print(f'GPA of {self.name} is: {round(sum1/y,2)}')


Bob = CSEStudent("Bob","20301018","Fall 2020")
Carol = CSEStudent("Carol","16301814","Fall 2020")
Anny = CSEStudent("Anny","18201234","Fall 2020")
print("#########################")
print(Bob.Details())
print("#########################")
print(Carol.Details())
print("#########################")
print(Anny.Details())
print("#########################")
Bob.addCourseWithMarks("CSE111",83.5,"CSE230",73.0,"CSE260",92.5)
Carol.addCourseWithMarks("CSE470",62.5,"CSE422",69.0,"CSE460",76.5,"CSE461",87.0)
Anny.addCourseWithMarks("CSE340",45.5,"CSE321",95.0,"CSE370",91.0)
print("----------------------------")
Bob.showGPA()
print("----------------------------")
Carol.showGPA()
print("----------------------------")
Anny.showGPA()
# Out:
# #########################
# Name: Bob
# ID: 20301018
# Current semester: Fall 2020
# #########################
# Name: Carol
# ID: 16301814
# Current semester: Fall 2020
# #########################
# Name: Anny
# ID: 18201234
# Current semester: Fall 2020
# #########################
# ----------------------------
# Bob has taken 3 courses
# CSE111:83
# CSE230:73
# CSE260:92
# GPA of Bob is: 3.43
# ----------------------------
# Carol has taken 4 courses
# CSE470:62
# CSE422:69
# CSE460:76
# CSE461:87
# GPA of Carol is: 2.82
# ----------------------------
# Anny has taken 3 courses
# CSE340:0.0
# CSE321:95
# CSE370:91
# GPA of Anny is: 2.67

# %%
# problem 11
class Transport:
    total_traveller = 0
    def __init__(self, name, fare):
        self.name = name
        self.baseFare = fare
    def __str__(self):
        s = "Name: "+self.name+", Base fare: "+str(self.baseFare)                          
        return s
# Write your codes here.
# Do not change the following lines of code.
class Bus(Transport):
    def __init__(self,name,price):
        super().__init__(name,price)
        self.dict_1={}
        print(f'Base-fare of volvo is {self.baseFare} Taka')
    def addPassengerWithBags(self,*passenger):
        Transport.total_traveller+=int(len(passenger)/2)
        for i in range(0,len(passenger),2):
            price=0
            if 3<=passenger[i+1]<=5:
                price=self.baseFare+60
                if passenger[i] not in self.dict_1.keys():
                    self.dict_1[passenger[i]]=price
            elif passenger[i+1]>5:
                price = self.baseFare + 105
                if passenger[i] not in self.dict_1.keys():
                    self.dict_1[passenger[i]]=price
            else:
                price=self.baseFare
                if passenger[i] not in self.dict_1.keys():
                    self.dict_1[passenger[i]]=price
    def __str__(self):
        s=''
        s+=super().__str__()
        s+=f'\nTotal passenger(s): {len(self.dict_1)}\n'
        s+=f'passengers details: \n'
        for key,val in self.dict_1.items():
            
            s+=f'Name: {key}, Fare: {val}\n'
        return s

       
class Train(Transport):
    def __init__(self, name, price):
        super().__init__(name, price)
        self.dict_1={}
        print(f'Base-fare of volvo is {self.baseFare} Taka')

    def addPassengerWithBags(self, *passenger):
        Transport.total_traveller+=int(len(passenger)/2)
#         print(f'Name: {self.name}, Base fare: {self.baseFare}')
#         print(f'Total passenger(s): {int(len(passenger)/2)}')
#         print(f'Passenger details: ')
        for i in range(0,len(passenger),2):
            price=0
            if 3<=passenger[i+1]<=5:
                price=self.baseFare+60
                if passenger[i] not in self.dict_1.keys():
                    self.dict_1[passenger[i]]=price
            elif passenger[i+1]>5:
                price = self.baseFare + 105
                if passenger[i] not in self.dict_1.keys():
                    self.dict_1[passenger[i]]=price
            else:
                price=self.baseFare
                if passenger[i] not in self.dict_1.keys():
                    self.dict_1[passenger[i]]=price
    def __str__(self):
        s=''
        s+=super().__str__()
        s+=f'\nTotal passenger(s): {len(self.dict_1)}\n'
        s+=f'passengers details: \n'
        for key,val in self.dict_1.items():
            
            s+=f'Name: {key}, Fare: {val}\n'
        return s

t1 = Bus("Volvo", 950)
print("=================================")
t1.addPassengerWithBags("David", 6, "Mike", 1, "Carol", 3)
print("=================================")
print(t1)
print("=================================")
t2 = Train("Silk City", 850)
print("=================================")
t2.addPassengerWithBags("Bob", 2, "Simon", 4)
print("=================================")
print(t2)
print("=================================")
print("Total Passengers in Transport: ", Transport.total_traveller )
# Out:
# Base-fare of volvo is 950 Taka
# ...
# Name: Volvo, Base fare: 950
# Total passenger(s): 3
# passengers details:
# Name: David, Fare: 1055
# Name: Mike, Fare: 950
# Name: Carol, Fare: 1010
#
# ...
# Base-fare of volvo is 850 Taka
# ...
# Name: Silk City, Base fare: 850
# Total passenger(s): 2
# passengers details:
# Name: Bob, Fare: 850
# Name: Simon, Fare: 910
#
# ...
# Total Passengers in Transport:  5

# %%
# problem 12
class AppleProduct:
    def __init__(self, name, model,base_price):
        self.name = name
        self.model = model
        self.base_price = base_price
    def companyInfo(self):
        st = ("Company Name: Apple\nFouder: SteveJobs, Steve Wozniak, Ronald Wayne\nCurrentCEO: Tim Cook\nAddress: Apple Inc, 2511Laguna Blvd, Elk Grove, CA 95758, UnitedStates")
        return st
    def feature(self):
        st = (f"Name: {self.name}\nProduct Model:{self.model}\nHardware Quality: ExcellentHardwares\nGuarantee/ Warranty: Apple Care")
        return st
    def __str__(self):
        print('This is apple product.')
    def calculatePrice(self):
        print('Total Price:', self.base_price)
# Write your codes here.
# Do not change the following lines of code.
class MacBookPro2020(AppleProduct):
    def __init__(self,name,name_model,ram,chip,tax):
        super().__init__(name,name_model,1299)
        self.ram=ram
        self.chip=chip
        self.tax=tax
        self.x=0

    def __str__(self):
        s=''
        s+="Product Details:\n"
        s+= f'{(super().feature())}\n'
        s+=f'Ram: {self.ram}\n'
        s+=f'Chip: {self.chip}\n'
        s+="Company details:\n"
        s+=f'{self.companyInfo()}'
        return s
    def calculatePrice(self):
        self.x=0
        print("Calculatting Total price: ")
        print("Base price: ",self.base_price)
        print("Tax:",self.tax,"%")
        self.x=(self.base_price+(self.base_price*self.tax/100))
        print("Total Price:",self.x)
    def __add__(self,other):
#         print(self.x)
#         print(other.x)
        return (self.x+other.x)
    
        
class iPhone12(AppleProduct):
    def __init__(self,name,name_model,ram,chip,tax):
        super().__init__(name,name_model,1299)
        self.ram=ram
        self.chip=chip
        self.tax=tax
        
        
    def __str__(self):
        s=''
        s+="Product Details:\n"
        s+= f'{(super().feature())}\n'
        s+=f'Ram: {self.ram}\n'
        s+=f'Chip: {self.chip}\n'
        s+="Company details:\n"
        s+=f'{self.companyInfo()}'
        return s
    def calculatePrice(self):
       
        print("Calculatting Total price: ")
        print("Base price: ",self.base_price)
        print("Tax:",self.tax,"%")
        self.x=(self.base_price+(self.base_price*self.tax/100))
        print("Total Price:",self.x)
    
    

m1 = MacBookPro2020('MacBook','MacBookPro2020', 8, 'M1', 10)
print(m1)
print('====================================')
m1.calculatePrice()
print('###################################')
iphone = iPhone12('iPhone', 'iPhone 12', 8,'A14', 5)
print(iphone)
print('====================================')
iphone.calculatePrice()
print('###################################')
print('Total Price of these two products:',end='')
print('%.2f Dollars'%(m1 + iphone))
# Out:
# Product Details:
# Name: MacBook
# Product Model:MacBookPro2020
# Hardware Quality: ExcellentHardwares
# Guarantee/ Warranty: Apple Care
# Ram: 8
# Chip: M1
# Company details:
# Company Name: Apple
# Fouder: SteveJobs, Steve Wozniak, Ronald Wayne
# CurrentCEO: Tim Cook
# Address: Apple Inc, 2511Laguna Blvd, Elk Grove, CA 95758, UnitedStates
# ...
# Calculatting Total price:
# Base price:  1299
# Tax: 10 %
# Total Price: 1428.9
# ###################################
# Product Details:
# Name: iPhone
# Product Model:iPhone 12
# Hardware Quality: ExcellentHardwares
# Guarantee/ Warranty: Apple Care
# Ram: 8
# Chip: A14
# Company details:
# Company Name: Apple
# Fouder: SteveJobs, Steve Wozniak, Ronald Wayne
# CurrentCEO: Tim Cook
# Address: Apple Inc, 2511Laguna Blvd, Elk Grove, CA 95758, UnitedStates
# ...
# Calculatting Total price:
# Base price:  1299
# Tax: 5 %
# Total Price: 1363.95
# ###################################
# Total Price of these two products:2792.85 Dollars

# %%
# problem 13
class University:
    name = "ABC University"
    numberOfStudents = 0
    admissionFee = 28000
    Library = 2000
    def __init__(self, n,i):
        self.stName = n
        self.stId = i
    def payment(self):
        return self.admissionFee + self.Library
    def __str__(self):
        return "Student Name: {}, ID: {}\nFee:{}".format(self.stName, self.stId, self.payment())
# Write your codes here.
# Do not change the following lines of code.
class CSE_dept(University):
    PerCreditFee = 6600
    SemesterFee = 7700
    LabFee = 2750
    def __init__(self,name,id,credit=6):
        super().__init__(name,id)
        self.credit=credit

        University.numberOfStudents += 1
    def payment_details(self):
        self.x=super().admissionFee+super().Library+7700+(6600*self.credit)+2750
        print("DETAILS:")
        print("Admission Fee:",super().admissionFee)
        print("Library Fee:",super().Library)
        print("Semester Fee:",CSE_dept.SemesterFee)
        print('per credit Fee:',CSE_dept.PerCreditFee)
        print("Number of credit:",self.credit)
        print("Lab fee:", CSE_dept.LabFee)
    def payment(self):
        return super().admissionFee+super().Library+CSE_dept.SemesterFee+(CSE_dept.PerCreditFee*self.credit)+CSE_dept.LabFee
    def __add__(self, other):
        m=self.x+other.x
        return m
class PHR_dept(University):
    PerCreditFee=6600
    SemesterFee=11000

    def __init__(self, name, id, credit=9):
        super().__init__(name, id)
        self.credit = credit
        University.numberOfStudents += 1

    def payment_details(self):
        self.y=super().admissionFee+super().Library+11000+(6600*self.credit)
        print("DETAILS:")
        print("Admission Fee:", super().admissionFee)
        print("Library Fee:", super().Library)
        print("Semester Fee:", PHR_dept.SemesterFee)
        print('per credit Fee:', PHR_dept.PerCreditFee)
        print("Number of credit:", self.credit)

    def payment(self):
        return super().admissionFee+super().Library+PHR_dept.SemesterFee+(PHR_dept.PerCreditFee*self.credit)
    def __add__(self, other):
        n=self.y+other.y
        return n

c1 = CSE_dept("Mary","5678")
print(c1)
c1.payment_details()
print("===========================")
p1 = PHR_dept("Simon","91011")
print(p1)
p1.payment_details()
print("===========================")
c2 = CSE_dept("Adam","1234", 12)
print(c2)
c2.payment_details()
print("===========================")
p2 = PHR_dept("David","121314", 15)
print(p2)
p2.payment_details()
print("===========================")
print("Total Number of Students:",University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
print("===========================")
print("Due to the pandemic, admission and library fees have been reduced for all departments. ")
University.admissionFee -= 1000
University.Library -= 100
print("The credit, semester and lab fees have been reduced for the CSE department. ")
CSE_dept.PerCreditFee -= 100
CSE_dept.SemesterFee -= 100
CSE_dept.LabFee -=100
print("The credit and semester fees have been reduced for the PHR department.\n ")
PHR_dept.PerCreditFee -= 100
PHR_dept.SemesterFee -= 1000
print(c1)
print(p1)
print(c2)
print(p2)
print("===========================")
print("Total Number of Students:", University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
# Out:
# Student Name: Mary, ID: 5678
# Fee:80050
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# per credit Fee: 6600
# Number of credit: 6
# Lab fee: 2750
# ...
# Student Name: Simon, ID: 91011
# Fee:100400
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# per credit Fee: 6600
# Number of credit: 9
# ...
# Student Name: Adam, ID: 1234
# Fee:119650
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# per credit Fee: 6600
# Number of credit: 12
# Lab fee: 2750
# ...
# Student Name: David, ID: 121314
# Fee:140000
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# per credit Fee: 6600
# Number of credit: 15
# ...
# Total Number of Students: 4
# Total University Revenue: 440100
# ...
# Due to the pandemic, admission and library fees have been reduced for all departments.
# The credit, semester and lab fees have been reduced for the CSE department.
# ...

# %%
# problem 14
class Library:
    Total_book = 1000
    borrow_data = {}

    def __init__(self,n,id):
        self.student_name = n
        self.student_id = id
    def borrowbook(self):
        print("A book is borrowed!")
    def __str__(self):
        return "Library: XYZ"
#Write your code here
class Student(Library):
    def __init__(self,name,id):
        super().__init__(name,id)
    def borrowbook(self,book_name,uni_id=""):
        self.book_name=book_name
        self.uni_id=uni_id
        if self.book_name not in super().borrow_data.keys():
            Library.Total_book -= 1
            print("A book is borrowed!")
            print(f'{self.book_name} book with the unique id {self.uni_id} is borrowed by {self.student_name}({self.student_id})')
            print(f'Number of books available for borrowing= {Library.Total_book}')
            if self.book_name not in super().borrow_data.keys():
                super().borrow_data[self.book_name]=[]
            super().borrow_data[self.book_name].append(self.student_name)
        else:
            print(f"Sorry {self.student_name} ! The Alchemist book is borrowed by {super().borrow_data[self.book_name][0]:}")
    def __str__(self):
        s=''
        s+=f"{super().__str__()}\n"
        s+=f'Student Name: {self.student_name} ID: {self.student_id}\n'
        s+=f'Books borrowed: {self.book_name}'
        return s
    def returnAllBooks(self):
        for key,val in  super().borrow_data.items():
            for i in val:
                if self.student_name==i:
                   x=[self.student_name]
                   if x in super().borrow_data.values():

                       Library.borrow_data = {key: val for key, val in Library.borrow_data.items() if val != x}
                       # super().borrow_data.popitem()
        print(f"All Books are returned by {self.student_name}.")
s1 = Student("Alice",18101259)
s1.borrowbook("The Alchemist", "Hdw652")
print("===============")
print(s1)
print("===============")
print(Library.borrow_data)
print("===============")
s1.borrowbook("Wuthering Heights")
print("===============")
print(s1)
print("===============")
s2= Student("David",18141777)
s2.borrowbook("The Alchemist", "Hdw652")
print("===============")
s2.borrowbook("The Vampyre")
print("===============")
print(Library.borrow_data)
print("===============")
s1.returnAllBooks()
print("===============")
print(Library.borrow_data)
# Out:
# A book is borrowed!
# The Alchemist book with the unique id Hdw652 is borrowed by Alice(18101259)
# Number of books available for borrowing= 999
# ...
# Library: XYZ
# Student Name: Alice ID: 18101259
# Books borrowed: The Alchemist
# ...
# {'The Alchemist': ['Alice']}
# ...
# A book is borrowed!
# Wuthering Heights book with the unique id  is borrowed by Alice(18101259)
# Number of books available for borrowing= 998
# ...
# Library: XYZ
# Student Name: Alice ID: 18101259
# Books borrowed: Wuthering Heights
# ...
# Sorry David ! The Alchemist book is borrowed by Alice
# ...
# A book is borrowed!
# The Vampyre book with the unique id  is borrowed by David(18141777)
# Number of books available for borrowing= 997
# ...
# {'The Alchemist': ['Alice'], 'Wuthering Heights': ['Alice'], 'The Vampyre': ['David']}
# ...
# All Books are returned by Alice.
# ...
# {'The Vampyre': ['David']}

# %%
# problem 15
class Player:
    database={}
    playerNo = 0
    def __init__(self,name,team,jerseyNo):
        self.name = name
        self.team = team
        self.jerseyNo = jerseyNo
    def __str__(self):
        return "Name:{}\nTeam:{}\nJerseyNo:{}".format(self.name,self.team,self.jerseyNo)
#Write your code here
class FootballPlayer(Player):
    def __init__(self,name,club,j_name,total_goal,retirement="Not yet retired"):
        super().__init__(name,club,j_name)
        self.total_goal=total_goal
        self.retirement=retirement
        Player.playerNo+=1
        self.player_number=Player.playerNo
        x=0
        for i in range(len(self.name)):
            if self.name[i]==" ":
                x=i+1
        s=str(self.player_number)+self.name[0]+self.name[x]+str(self.jerseyNo)
        if s not in Player.database.keys():
            Player.database[s]=[]
        Player.database[s].append(self.name)
        Player.database[s].append(self.team)
        Player.database[s].append(self.jerseyNo)
        Player.database[s].append(self.total_goal)
        Player.database[s].append(self.retirement)

    def __str__(self):
        s=''
        s+=f"{super().__str__()}\n"
        s+=f'Goals Scored: {self.total_goal}\n'
        if self.retirement=="":
            s+=(f'Retirement date: Not yet retired')
        else:
            s+=(f'Retirement date: {self.retirement}')
        return s
    def createPlayer(name,club,j_name,total_goal,retirement="Not yet retired"):
        # self.name=name
        # self.team=club
        # self.jerseyNo=j_name
        # self.total_goal=total_goal
        # self.retirement=retirement
        return FootballPlayer(name,club,j_name,total_goal,retirement)


print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
print("#################################")
p1 = FootballPlayer("Lionel Messi","Barcelona",10,231)
print("------Details of the player------")
print(p1)
print("#################################")
p2 = FootballPlayer("Cristiano Ronaldo","Juventus",7,215)
print("------Details of the player------")
print(p2)
print("#################################")
p3 = FootballPlayer.createPlayer("Miroslav Klose","Lazio",11,71,"11 Aug,2014")
print("------Details of the player------")
print(p3)
print("#################################")
print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
# Out:
# Number of players: 0
# Player Database: {}
# #################################
# ------Details of the player------
# Name:Lionel Messi
# Team:Barcelona
# JerseyNo:10
# Goals Scored: 231
# Retirement date: Not yet retired
# #################################
# ------Details of the player------
# Name:Cristiano Ronaldo
# Team:Juventus
# JerseyNo:7
# Goals Scored: 215
# Retirement date: Not yet retired
# #################################
# ------Details of the player------
# Name:Miroslav Klose
# Team:Lazio
# JerseyNo:11
# Goals Scored: 71
# Retirement date: 11 Aug,2014
# #################################
# Number of players: 3
# Player Database: {'1LM10': ['Lionel Messi', 'Barcelona', 10, 231, 'Not yet retired'], '2CR7': ['Cristiano Ronaldo', 'Juventus', 7, 215, 'Not yet retired'], '3MK11': ['Miroslav Klose', 'Lazio', 11, 71, '11 Aug,2014']}
